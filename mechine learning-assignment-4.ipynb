# %% [markdown]
# # **Using Decision Treem model over iris Dataset**

# %% [markdown]
# # **Problem Statement**
# # This data set consists of the physical parameters of three species of flower — Versicolor, Setosa and Virginica. The numeric parameters which the dataset contains are Sepal width, Sepal length, Petal width and Petal length. In this data we will be predicting the classes of the flowers based on these parameters.The data consists of continuous numeric values which describe the dimensions of the respective features. We will be training the model based on these features.

# %% [markdown]
# # **Importing importent libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **load the iris dataset from sklearn libraries**

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %% [markdown]
# # **load the iris data from seaborn libraries**

# %%
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # **checking for missing values**

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # **divide the iris data into X and y**

# %%
X = data.drop('species', axis=1)
y = data['species']

# %% [markdown]
# # **apply train test split on x and y**
# ## import train test split from sklearn libraries

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size= 0.25, random_state = 1)
X_train.shape, X_test.shape
# Out:
# ((112, 4), (38, 4))

# %% [markdown]
# # Apply Decision Tree from train dataset with the help of RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 100, random_state=1)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %% [markdown]
# # make prediction on the testing dataset

# %%
y_pred = rfc.predict(X_test)

# %% [markdown]
# # Evaluate the accuracy of the model
# # import the import libraries

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.9736842105263158

# %% [markdown]
# # Again we apply decision tree on train data
# # import importent libraries

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # plot the dtc

# %%
from sklearn import tree
fig =plt.figure(figsize=(25,20))
_ = tree.plot_tree(dtc,
                   feature_names = X.columns,
                   filled =True)
